# %% [markdown]
# # Spidroin curation
# Setting up the required Python packages

# %%
import os
import pandas as pd
import subprocess
import time

from spider_silkome_module import (
    RAW_DATA_DIR,
    INTERIM_DATA_DIR,
    EXTERNAL_DATA_DIR,
    PROCESSED_DATA_DIR
)
from spider_silkome_module import (
    Attributes,
    GFFData
)
from spider_silkome_module import (
    extract_positions_from_gff,
    positions_export
)
# Out:
# 2025-10-10 13:48:28.875 | INFO     | spider_silkome_module.config:<module>:11 - PROJ_ROOT path is: /home/gyk/project/spider_silkome

# %% [markdown]
# Definition of the path for relevant data

# %%
spider_species_file = f"{EXTERNAL_DATA_DIR}/organisms.csv"
mechanical_properties_file = f"{EXTERNAL_DATA_DIR}/mechanical_properties.csv"
spidroin_fasta_file = f"{EXTERNAL_DATA_DIR}/spider-silkome-database.v1.prot.fixed.fasta"
spider_genome_path = f"{RAW_DATA_DIR}/spider_genome"
spidroin_path = f"{INTERIM_DATA_DIR}/spidroin"

# %% [markdown]
# 使用 MMseq2 对 Spidroin 蛋白的 N/C 端序列进行去冗余。

# %%
mmseqs_output_dir=f"{INTERIM_DATA_DIR}/mmseqs"
spidroin_fasta_file_rep = f"{mmseqs_output_dir}/{spidroin_fasta_file.split('/')[-1].replace('.fasta', '')}_rep_seq.fasta"
if not os.path.exists(spidroin_fasta_file_rep):
    os.makedirs(mmseqs_output_dir, exist_ok=True)
    cmd = f"pixi run --environment mmseqs mmseqs easy-cluster {spidroin_fasta_file} {mmseqs_output_dir}/{spidroin_fasta_file.split('/')[-1].replace('.fasta', '')} {mmseqs_output_dir}/tmp --min-seq-id 0.9 -c 0.8 --cov-mode 1"
    subprocess.run(cmd, shell=True)
spidroin_fasta_file_rep_manually = spidroin_fasta_file_rep.replace('.fasta', '_manually.fasta')
# Out:
# easy-cluster /home/gyk/project/spider_silkome/data/external/spider-silkome-database.v1.prot.fixed.fasta /home/gyk/project/spider_silkome/data/interim/mmseqs/spider-silkome-database.v1.prot.fixed /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp --min-seq-id 0.9 -c 0.8 --cov-mode 1
#
# MMseqs Version:                     	18.8cc5c
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# Target search mode                  	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.8
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias scale            	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Mask lower letter repeating N times 	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	80
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.9
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Weight file name
# Cluster Weight threshold            	0.9
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	true
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
# Database type                       	0
# Shuffle input database              	true
# Createdb mode                       	1
# Write lookup file                   	0
# Offset of numeric ids               	0
# Use GPU                             	0
#
# createdb /home/gyk/project/spider_silkome/data/external/spider-silkome-database.v1.prot.fixed.fasta /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input --createdb-mode 1 --write-lookup 0
#
# Shuffle database cannot be combined with --createdb-mode 1
# We recompute with --shuffle 0
# Converting sequences
# [Multiline fasta can not be combined with --createdb-mode 0
# We recompute with --createdb-mode 1
# Time for merging to input_h: 0h 0m 0s 0ms
# Time for merging to input: 0h 0m 0s 0ms
# [=
# Time for merging to input_h: 0h 0m 0s 0ms
# Time for merging to input: 0h 0m 0s 1ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 89ms
# Create directory /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp
# cluster /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp --max-seqs 20 -c 0.8 --cov-mode 1 --spaced-kmer-mode 1 --alignment-mode 3 -e 0.001 --min-seq-id 0.9 --remove-tmp-files 1
#
# Set cluster sensitivity to -s 1.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 1
# linclust /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/clu_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 80 --compressed 0 -v 3 --cluster-weight-threshold 0.9 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 1 --force-reuse 0
#
# kmermatcher /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.9 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 1 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 80 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# kmermatcher /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.9 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 1 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 80 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Database size: 11155 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 11.15K 0s 12ms
# Sort kmer 0h 0m 0s 7ms
# Sort by rep. sequence 0h 0m 0s 5ms
# Time for fill: 0h 0m 0s 5ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 64ms
# rescorediagonal /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.8 -a 0 --cov-mode 1 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 80 --compressed 0 -v 3
#
# [=================================================================] 11.15K 0s 10ms
# Time for merging to pref_rescore1: 0h 0m 0s 9ms
# Time for processing: 0h 0m 0s 64ms
# clust /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_rescore1 /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 80 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 13ms
#
# Size of the sequence database: 11155
# Size of the alignment database: 11155
# Number of clusters: 8481
#
# Writing results 0h 0m 0s 1ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 20ms
# createsubdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/order_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 3ms
# createsubdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/order_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 3ms
# filterdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_filter1 /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_filter2 --filter-file /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/order_redundancy --threads 80 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 8.48K 0s 8ms
# Time for merging to pref_filter2: 0h 0m 0s 7ms
# Time for processing: 0h 0m 0s 47ms
# rescorediagonal /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/input_step_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/input_step_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_filter2 /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.8 -a 0 --cov-mode 1 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 80 --compressed 0 -v 3
#
# [=================================================================] 8.48K 0s 11ms
# Time for merging to pref_rescore2: 0h 0m 0s 7ms
# Time for processing: 0h 0m 0s 68ms
# align /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/input_step_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/input_step_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_rescore2 /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 80 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 8481 type: Aminoacid
# Target database size: 8481 type: Aminoacid
# Calculation of alignments
# [=================================================================] 8.48K 0s 153ms
# Time for merging to aln: 0h 0m 0s 8ms
# 18607 alignments calculated
# 9660 sequence pairs passed the thresholds (0.519159 of overall calculated)
# 1.139017 hits per query sequence
# Time for processing: 0h 0m 0s 204ms
# clust /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/input_step_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/aln /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 80 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 12ms
#
# Size of the sequence database: 8481
# Size of the alignment database: 8481
# Number of clusters: 7530
#
# Writing results 0h 0m 0s 1ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 18ms
# mergeclusters /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/clu_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pre_clust /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/clust --threads 80 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 8.48K 0s 7ms
# Clustering step 2
# [=================================================================] 7.53K 0s 18ms
# Write merged clustering
# [=================================================================] 11.15K 0s 51ms
# Time for merging to clu_redundancy: 0h 0m 0s 7ms
# Time for processing: 0h 0m 0s 68ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_filter1 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_rescore1 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pre_clust -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_filter2 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/pref_rescore2 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/aln -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/linclust/1171994881477103379/clust -v 3
#
# Time for processing: 0h 0m 0s 0ms
# createsubdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/clu_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 3ms
# prefilter /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/input_step_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/input_step_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.8 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 80 --compressed 0 -v 3
#
# Query database size: 7530 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 7530 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 7.53K 0s 21ms
# Index table: Masked residues: 1326835
# Index table: fill
# [=================================================================] 7.53K 0s 15ms
# Index statistics
# Entries:          461555
# DB size:          490 MB
# Avg k-mer size:   0.007212
# Top 10 k-mers
#     NMFSAE	1520
#     PGSCLV	881
#     CDLQLE	681
#     QTGVQF	597
#     SKKQNM	538
#     NERLMF	498
#     QFNILI	480
#     ALMFSM	451
#     CELQLE	423
#     ASPLCD	382
# Time for index table init: 0h 0m 0s 683ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 7530
# Target db start 1 to 7530
# [=================================================================] 7.53K 0s 32ms
#
# 0.602821 k-mers per position
# 3330 DB matches per sequence
# 0 overflows
# 18 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 7ms
# Time for processing: 0h 0m 0s 924ms
# align /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/input_step_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/input_step_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/pref_step0 /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.9 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 80 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 7530 type: Aminoacid
# Target database size: 7530 type: Aminoacid
# Calculation of alignments
# [=================================================================] 7.53K 1s 685ms
# Time for merging to aln_step0: 0h 0m 0s 7ms
# 93405 alignments calculated
# 8352 sequence pairs passed the thresholds (0.089417 of overall calculated)
# 1.109163 hits per query sequence
# Time for processing: 0h 0m 1s 733ms
# clust /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/input_step_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/aln_step0 /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 80 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 11ms
#
# Size of the sequence database: 7530
# Size of the alignment database: 7530
# Number of clusters: 7136
#
# Writing results 0h 0m 0s 1ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 18ms
# mergeclusters /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/clu_redundancy /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/clu_step0 --threads 80 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 7.53K 0s 6ms
# Clustering step 2
# [=================================================================] 7.14K 0s 19ms
# Write merged clustering
# [=================================================================] 11.15K 0s 49ms
# Time for merging to clu: 0h 0m 0s 6ms
# Time for processing: 0h 0m 0s 65ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/clu_redundancy -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/pref_step0 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/aln_step0 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_tmp/14512155558865545692/clu_step0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# createtsv /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/cluster.tsv --threads 80 -v 3
#
# Time for merging to cluster.tsv: 0h 0m 0s 7ms
# Time for processing: 0h 0m 0s 52ms
# result2repseq /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_rep --db-load-mode 0 --compressed 0 --threads 80 -v 3
#
# [=================================================================] 7.14K 0s 5ms
# Time for merging to clu_rep: 0h 0m 0s 17ms
# Time for processing: 0h 0m 0s 75ms
# result2flat /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_rep /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/rep_seq.fasta --use-fasta-header -v 3
#
# Time for processing: 0h 0m 0s 15ms
# createseqfiledb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_seqs --threads 80 -v 3
#
# [=================================================================] 7.14K 0s 9ms
# Time for merging to clu_seqs: 0h 0m 0s 6ms
# Time for processing: 0h 0m 0s 48ms
# result2flat /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_seqs /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/all_seqs.fasta -v 3
#
# Time for processing: 0h 0m 0s 28ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/input_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_seqs -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu_rep -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb /home/gyk/project/spider_silkome/data/interim/mmseqs/tmp/18438224705311594293/clu -v 3
#
# Time for processing: 0h 0m 0s 1ms

# %% [markdown]
# Use miniprot to align the C-terminal and N-terminal sequences of the spidroin gene sequences to the genome of the new species.

# %%
spidroin_files = os.listdir(spidroin_path)
spider_genomes = [f for f in os.listdir(spider_genome_path) if f.endswith(".fa.gz")]
gnome_mpi_path = f"{INTERIM_DATA_DIR}/genome_mpi"
miniprot_output_path = f"{INTERIM_DATA_DIR}/miniprot"
os.makedirs(gnome_mpi_path, exist_ok=True)
os.makedirs(miniprot_output_path, exist_ok=True)
for spider_genome in spider_genomes:
    spider = spider_genome.split(".")[0]
    index_cmd = f"miniprot -t70 -d {gnome_mpi_path}/{spider}.mpi {spider_genome_path}/{spider_genome}"
    if not os.path.exists(f"{gnome_mpi_path}/{spider}.mpi"):
        indext_start_time = time.time()
        subprocess.run(index_cmd, shell=True)
        indext_end_time = time.time()
        print(f"Indexing {spider} takes {indext_end_time - indext_start_time} seconds")
    else:
        print(f"Indexing {spider} already exists")

    output_dir = f"{miniprot_output_path}/{spider}_all"
    os.makedirs(output_dir, exist_ok=True)
    align_cmd = f"miniprot -t 70 -I --gff {gnome_mpi_path}/{spider}.mpi {spidroin_fasta_file_rep_manually} > {output_dir}/{spider}.gff"
    if not os.path.exists(f"{output_dir}/{spider}.gff"):
        align_start_time = time.time()
        subprocess.run(align_cmd, shell=True)
        align_end_time = time.time()
        print(f"Alignment {spider} takes {align_end_time - align_start_time} seconds")
    else:
        print(f"Alignment {spider} already exists")

    if not os.path.exists(f"{output_dir}/{spider}.mRNA.gff"):
        grep_cmd = f"grep 'mRNA' {output_dir}/{spider}.gff > {output_dir}/{spider}.mRNA.gff"
        subprocess.run(grep_cmd, shell=True)
    else:
        print(f"mRNA gff file already exists")

    if os.path.exists(f"{output_dir}/{spider}.mRNA.gff"):
        mRNA_gff = pd.read_csv(f"{output_dir}/{spider}.mRNA.gff", sep='\t', header=None)
        gff_header = ["seqid", "source", "type", "start", "end", "score", "strand", "frame", "attribute"]
        mRNA_gff.columns = gff_header
        spidroins = list(set([row["attribute"].split(';')[-1].split('|')[-2] for index, row in mRNA_gff.iterrows()]))
        print(f"Total number of spidroins in {spider}: {len(spidroins)}\n{spidroins}")
        for spidroin in spidroins:
            gff_spidroin_output = f"{output_dir}/{spider}.mRNA.{spidroin}.gff"
            if not os.path.exists(gff_spidroin_output):
                grep_cmd = f"grep '|{spidroin}|' {output_dir}/{spider}.mRNA.gff > {gff_spidroin_output}"
                subprocess.run(grep_cmd, shell=True)
            else:
                print(f"{spider}.mRNA.{spidroin}.gff already exists")
# Out:
# Indexing Trichonephila_clavata already exists
# [M::mp_idx_restore@3.536*1.00] loaded the index
# [M::mp_mapopt_set_max_intron] set max intron size to 184590
# [M::mp_idx_print_stat] 2364518 distinct k-mers; mean occ of infrequent k-mers: 391.92; 573 frequent k-mers accounting for 15240950 occurrences
# [M::worker_pipeline::26.333*54.50] mapped 4096 sequences
# [M::worker_pipeline::43.620*54.62] mapped 3040 sequences
# [M::main] Version: 0.18-r281
# [M::main] CMD: miniprot -t 70 -I --gff /home/gyk/project/spider_silkome/data/interim/genome_mpi/Trichonephila_clavata.mpi /home/gyk/project/spider_silkome/data/interim/mmseqs/spider-silkome-database.v1.prot.fixed_rep_seq_manually.fasta
# [M::main] Real time: 43.951 sec; CPU: 2382.903 sec; Peak RSS: 17.852 GB
# Alignment Trichonephila_clavata takes 44.06230330467224 seconds
# Total number of spidroins in Trichonephila_clavata: 18
# ['MaSp3', 'Pflag', 'MiSp', 'MaSp2', 'AcSp', 'CySp', 'MaSp3B', 'Spidroin', 'Putative_spidroin', 'CrSp', 'AgSp2', 'MaSp1', 'Ampullate_spidroin', 'MaSp', 'Flag', 'AgSp1', 'MaSp2B', 'PySp']
# Indexing Araneus_ventricosus already exists
# Alignment Araneus_ventricosus already exists
# mRNA gff file already exists
# Total number of spidroins in Araneus_ventricosus: 17
# ['Pflag', 'MaSp3', 'MiSp', 'CySp', 'AcSp', 'MaSp3B', 'Putative_spidroin', 'Spidroin', 'AgSp2', 'MaSp1', 'Ampullate_spidroin', 'MaSp', 'Flag', 'AgSp1', 'MaSp2B', 'MaSp2', 'PySp']
# Araneus_ventricosus.mRNA.Pflag.gff already exists
# Araneus_ventricosus.mRNA.MaSp3.gff already exists
# Araneus_ventricosus.mRNA.MiSp.gff already exists
# Araneus_ventricosus.mRNA.CySp.gff already exists
# Araneus_ventricosus.mRNA.AcSp.gff already exists
# Araneus_ventricosus.mRNA.MaSp3B.gff already exists
# Araneus_ventricosus.mRNA.Putative_spidroin.gff already exists
# Araneus_ventricosus.mRNA.Spidroin.gff already exists
# Araneus_ventricosus.mRNA.AgSp2.gff already exists
# Araneus_ventricosus.mRNA.MaSp1.gff already exists
# Araneus_ventricosus.mRNA.Ampullate_spidroin.gff already exists
# Araneus_ventricosus.mRNA.MaSp.gff already exists
# Araneus_ventricosus.mRNA.Flag.gff already exists
# Araneus_ventricosus.mRNA.AgSp1.gff already exists
# Araneus_ventricosus.mRNA.MaSp2B.gff already exists
# Araneus_ventricosus.mRNA.MaSp2.gff already exists
# Araneus_ventricosus.mRNA.PySp.gff already exists

# %%
spidroins = ['MaSp3', 'Pflag', 'MiSp', 'MaSp2', 'AcSp', 'CySp',
'MaSp3B', 'Spidroin', 'Putative_spidroin', 'CrSp', 'AgSp2', 'MaSp1',
'Ampullate_spidroin', 'MaSp', 'Flag', 'AgSp1', 'MaSp2B', 'PySp']
all_gff_records = []
all_csv = pd.DataFrame()
for spidroin in spidroins:
    # spidroin = "MiSp"
    spider = "Trichonephila_clavata"
    output_dir = f"{miniprot_output_path}/{spider}_all"
    spidroin_gff = f"{output_dir}/{spider}.mRNA.{spidroin}.gff"
    attr_dict = {}
    spidroin_gff_data = []
    with open(spidroin_gff, 'r') as f:
        for line in f:
            if line.startswith('#'):
                continue

            fields = line.strip().split('\t')

            # Analysis of the attributes field
            for attr in fields[8].split(';'):
                if '=' in attr:
                    key, value = attr.split('=', 1)
                    attr_dict[key] = value

            # Create attributes object
            attr_obj = Attributes(
                ID=attr_dict['ID'],
                Rank=int(attr_dict['Rank']),
                Identity=float(attr_dict['Identity']),
                Positive=float(attr_dict['Positive']),
                Target=attr_dict['Target'].split('|')
            )

            # Create gff_data object and add to list
            spidroin_gff_data.append(GFFData(
                seqid=fields[0],
                source=fields[1],
                type=fields[2],
                start=int(fields[3]),
                end=int(fields[4]),
                score=float(fields[5]),
                strand=fields[6],
                frame=fields[7],
                attributes=attr_obj
            ))

    # Sort by positive with descending order
    spidroin_gff_data.sort(key=lambda x: x.attributes.Positive, reverse=True)
    # Extract positions
    positions = extract_positions_from_gff(spidroin_gff_data, positive_threshold=0.5)
    # Export data
    # Export CSV data
    csv_output = spidroin_gff.replace('.gff', '.csv')
    df = positions_export(positions, csv_output, format='csv')
    all_csv = pd.concat([all_csv, df], ignore_index=True)

    # Export GFF data
    gff_output = spidroin_gff.replace('.gff', '.combined.gff')
    gff_records = positions_export(
        positions,
        gff_output,
        format='gff',
        spidroin=spidroin,
        min_length=1000, # Set minimum gene length threshold
        max_length=100000, # Set maximum gene length threshold
        extension_length=10000 # Set length to extend when start or end is missing
)

    all_gff_records.extend(gff_records)

# Convert to DataFrame and save
if all_gff_records:
    df_combined = pd.DataFrame(all_gff_records)
    # Sort by seqid (chromosome) and start position with natural sorting
    df_combined['seqid_sort'] = df_combined['seqid'].str.extract(r'(\d+)').astype(float)
    df_combined = df_combined.sort_values(['seqid_sort', 'start']).drop('seqid_sort', axis=1)
    # Write to GFF file
    with open(f"{PROCESSED_DATA_DIR}/{spider}_combined.gff", 'w') as f:
        f.write("##gff-version 3\n")
        df_combined.to_csv(f, sep='\t', header=False, index=False)
else:
    print(f"No GFF records to combine for {spider}")

if not all_csv.empty:
    all_csv.to_csv(f"{PROCESSED_DATA_DIR}/{spider}_combined.csv", index=False)
# Out:
# 2025-10-10 14:50:27.427 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp3.csv
# 2025-10-10 14:50:27.427 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 174
# 2025-10-10 14:50:27.428 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 8
# 2025-10-10 14:50:27.428 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 166
# 2025-10-10 14:50:27.430 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp3.combined.gff
# 2025-10-10 14:50:27.430 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 8
# 2025-10-10 14:50:27.436 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Pflag.csv
# 2025-10-10 14:50:27.436 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 1
# 2025-10-10 14:50:27.437 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 0
# 2025-10-10 14:50:27.437 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 1
# 2025-10-10 14:50:27.438 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Pflag.combined.gff
# 2025-10-10 14:50:27.439 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 0
# 2025-10-10 14:50:27.509 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MiSp.csv
# 2025-10-10 14:50:27.509 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 4282
# 2025-10-10 14:50:27.509 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 10
# 2025-10-10 14:50:27.509 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 4272
# 2025-10-10 14:50:27.521 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MiSp.combined.gff
# 2025-10-10 14:50:27.521 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 10
# 2025-10-10 14:50:27.534 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp2.csv
# 2025-10-10 14:50:27.534 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 393
# 2025-10-10 14:50:27.535 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 5
# 2025-10-10 14:50:27.535 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 388
# 2025-10-10 14:50:27.537 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp2.combined.gff
# 2025-10-10 14:50:27.537 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 5
# 2025-10-10 14:50:27.544 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.AcSp.csv
# 2025-10-10 14:50:27.544 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 63
# 2025-10-10 14:50:27.544 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 1
# 2025-10-10 14:50:27.545 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 62
# 2025-10-10 14:50:27.545 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.AcSp.combined.gff
# 2025-10-10 14:50:27.546 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 1
# 2025-10-10 14:50:27.557 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.CySp.csv
# 2025-10-10 14:50:27.557 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 528
# 2025-10-10 14:50:27.558 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 0
# 2025-10-10 14:50:27.558 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 528
# 2025-10-10 14:50:27.561 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.CySp.combined.gff
# 2025-10-10 14:50:27.561 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 0
# 2025-10-10 14:50:27.565 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp3B.csv
# 2025-10-10 14:50:27.565 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 17
# 2025-10-10 14:50:27.565 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 4
# 2025-10-10 14:50:27.565 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 13
# 2025-10-10 14:50:27.566 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp3B.combined.gff
# 2025-10-10 14:50:27.566 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 4
# 2025-10-10 14:50:27.641 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Spidroin.csv
# 2025-10-10 14:50:27.641 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 290
# 2025-10-10 14:50:27.641 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 16
# 2025-10-10 14:50:27.641 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 274
# 2025-10-10 14:50:27.643 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Spidroin.combined.gff
# 2025-10-10 14:50:27.644 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 16
# 2025-10-10 14:50:27.645 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Putative_spidroin.csv
# 2025-10-10 14:50:27.645 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 0
# 2025-10-10 14:50:27.645 | WARNING  | spider_silkome_module.export:_export_to_csv:184 - No data to export
# 2025-10-10 14:50:27.646 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Putative_spidroin.combined.gff
# 2025-10-10 14:50:27.646 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 0
# 2025-10-10 14:50:27.649 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.CrSp.csv
# 2025-10-10 14:50:27.649 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 1
# 2025-10-10 14:50:27.649 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 0
# 2025-10-10 14:50:27.649 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 1
# 2025-10-10 14:50:27.650 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.CrSp.combined.gff
# 2025-10-10 14:50:27.650 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 0
# 2025-10-10 14:50:27.657 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.AgSp2.csv
# 2025-10-10 14:50:27.657 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 8
# 2025-10-10 14:50:27.657 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 1
# 2025-10-10 14:50:27.657 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 7
# 2025-10-10 14:50:27.658 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.AgSp2.combined.gff
# 2025-10-10 14:50:27.658 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 1
# 2025-10-10 14:50:27.676 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp1.csv
# 2025-10-10 14:50:27.676 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 365
# 2025-10-10 14:50:27.676 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 11
# 2025-10-10 14:50:27.676 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 354
# 2025-10-10 14:50:27.678 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp1.combined.gff
# 2025-10-10 14:50:27.678 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 11
# 2025-10-10 14:50:27.690 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Ampullate_spidroin.csv
# 2025-10-10 14:50:27.690 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 365
# 2025-10-10 14:50:27.690 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 10
# 2025-10-10 14:50:27.690 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 355
# 2025-10-10 14:50:27.692 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Ampullate_spidroin.combined.gff
# 2025-10-10 14:50:27.692 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 10
# 2025-10-10 14:50:27.709 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp.csv
# 2025-10-10 14:50:27.709 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 695
# 2025-10-10 14:50:27.710 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 14
# 2025-10-10 14:50:27.710 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 681
# 2025-10-10 14:50:27.712 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp.combined.gff
# 2025-10-10 14:50:27.712 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 14
# 2025-10-10 14:50:27.722 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Flag.csv
# 2025-10-10 14:50:27.722 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 80
# 2025-10-10 14:50:27.722 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 4
# 2025-10-10 14:50:27.723 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 76
# 2025-10-10 14:50:27.724 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Flag.combined.gff
# 2025-10-10 14:50:27.724 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 4
# 2025-10-10 14:50:27.731 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.AgSp1.csv
# 2025-10-10 14:50:27.731 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 36
# 2025-10-10 14:50:27.731 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 1
# 2025-10-10 14:50:27.731 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 35
# 2025-10-10 14:50:27.732 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.AgSp1.combined.gff
# 2025-10-10 14:50:27.732 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 1
# 2025-10-10 14:50:27.736 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp2B.csv
# 2025-10-10 14:50:27.736 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 54
# 2025-10-10 14:50:27.736 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 3
# 2025-10-10 14:50:27.737 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 51
# 2025-10-10 14:50:27.738 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp2B.combined.gff
# 2025-10-10 14:50:27.738 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 3
# 2025-10-10 14:50:27.748 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.PySp.csv
# 2025-10-10 14:50:27.748 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 302
# 2025-10-10 14:50:27.748 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 2
# 2025-10-10 14:50:27.748 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 300
# 2025-10-10 14:50:27.750 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.PySp.combined.gff
# 2025-10-10 14:50:27.750 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 2
