# %% [markdown]
# # Spidroin curation
# Setting up the required Python packages

# %%
import os
import pandas as pd
from Bio import SeqIO
import subprocess
import time
from dataclasses import dataclass
from collections import defaultdict

from spider_silkome_module import (
    RAW_DATA_DIR,
    INTERIM_DATA_DIR,
    EXTERNAL_DATA_DIR,
    PROCESSED_DATA_DIR
)
from spider_silkome_module import (
    Attributes,
    GFFData
)
from spider_silkome_module import (
    extract_positions_from_gff,
    positions_export
)
# Out:
# 2025-10-09 09:34:25.074 | INFO     | spider_silkome_module.config:<module>:11 - PROJ_ROOT path is: /home/gyk/project/spider_silkome

# %% [markdown]
# Definition of the path for relevant data

# %%
spider_species_file = f"{EXTERNAL_DATA_DIR}/organisms.csv"
mechanical_properties_file = f"{EXTERNAL_DATA_DIR}/mechanical_properties.csv"
spidroin_fasta_file = f"{EXTERNAL_DATA_DIR}/spider-silkome-database.v1.prot.fixed.fasta"
spider_genome_path = f"{RAW_DATA_DIR}/spider_genome"
spidroin_path = f"{INTERIM_DATA_DIR}/spidroin"

# %% [markdown]
# Use miniprot to align the C-terminal and N-terminal sequences of the spidroin gene sequences to the genome of the new species.

# %%
spidroin_files = os.listdir(spidroin_path)
spider_genomes = [f for f in os.listdir(spider_genome_path) if f.endswith(".fa.gz")]
gnome_mpi_path = f"{INTERIM_DATA_DIR}/genome_mpi"
miniprot_output_path = f"{INTERIM_DATA_DIR}/miniprot"
os.makedirs(gnome_mpi_path, exist_ok=True)
os.makedirs(miniprot_output_path, exist_ok=True)
for spider_genome in spider_genomes:
    spider = spider_genome.split(".")[0]
    index_cmd = f"miniprot -t70 -d {gnome_mpi_path}/{spider}.mpi {spider_genome_path}/{spider_genome}"
    if not os.path.exists(f"{gnome_mpi_path}/{spider}.mpi"):
        indext_start_time = time.time()
        subprocess.run(index_cmd, shell=True)
        indext_end_time = time.time()
        print(f"Indexing {spider} takes {indext_end_time - indext_start_time} seconds")
    else:
        print(f"Indexing {spider} already exists")

    output_dir = f"{miniprot_output_path}/{spider}_all"
    os.makedirs(output_dir, exist_ok=True)
    align_cmd1 = f"miniprot -t 70 -I --gff {gnome_mpi_path}/{spider}.mpi {spidroin_fasta_file} > {output_dir}/{spider}.gff"
    align_cmd2 = f"miniprot -t 70 -I --aln {gnome_mpi_path}/{spider}.mpi {spidroin_fasta_file} > {output_dir}/{spider}.aln"
    if not os.path.exists(f"{output_dir}/{spider}.gff"):
        align_start_time = time.time()
        subprocess.run(align_cmd1, shell=True)
        align_end_time = time.time()
        print(f"Alignment {spider} takes {align_end_time - align_start_time} seconds")
    else:
        print(f"Alignment {spider} already exists")

    if not os.path.exists(f"{output_dir}/{spider}.mRNA.gff"):
        grep_cmd = f"grep 'mRNA' {output_dir}/{spider}.gff > {output_dir}/{spider}.mRNA.gff"
        subprocess.run(grep_cmd, shell=True)
    else:
        print(f"mRNA gff file already exists")

    if os.path.exists(f"{output_dir}/{spider}.mRNA.gff"):
        mRNA_gff = pd.read_csv(f"{output_dir}/{spider}.mRNA.gff", sep='\t', header=None)
        gff_header = ["seqid", "source", "type", "start", "end", "score", "strand", "frame", "attribute"]
        mRNA_gff.columns = gff_header
        spidroins = list(set([row["attribute"].split(';')[-1].split('|')[-2] for index, row in mRNA_gff.iterrows()]))
        print(f"Total number of spidroins in {spider}: {len(spidroins)}\n{spidroins}")
        for spidroin in spidroins:
            gff_spidroin_output = f"{output_dir}/{spider}.mRNA.{spidroin}.gff"
            if not os.path.exists(gff_spidroin_output):
                grep_cmd = f"grep '|{spidroin}|' {output_dir}/{spider}.mRNA.gff > {gff_spidroin_output}"
                subprocess.run(grep_cmd, shell=True)
            else:
                print(f"{spider}.mRNA.{spidroin}.gff already exists")
# Out:
# Indexing Trichonephila_clavata already exists
# Alignment Trichonephila_clavata already exists
# mRNA gff file already exists
# Total number of spidroins in Trichonephila_clavata: 18
# ['MaSp1', 'Flag', 'MaSp2', 'Spidroin', 'Ampullate_spidroin', 'AcSp', 'MaSp', 'CySp', 'Putative_spidroin', 'PySp', 'MaSp2B', 'CrSp', 'MaSp3B', 'AgSp2', 'Pflag', 'MaSp3', 'MiSp', 'AgSp1']
# Trichonephila_clavata.mRNA.MaSp1.gff already exists
# Trichonephila_clavata.mRNA.Flag.gff already exists
# Trichonephila_clavata.mRNA.MaSp2.gff already exists
# Trichonephila_clavata.mRNA.Spidroin.gff already exists
# Trichonephila_clavata.mRNA.Ampullate_spidroin.gff already exists
# Trichonephila_clavata.mRNA.AcSp.gff already exists
# Trichonephila_clavata.mRNA.MaSp.gff already exists
# Trichonephila_clavata.mRNA.CySp.gff already exists
# Trichonephila_clavata.mRNA.Putative_spidroin.gff already exists
# Trichonephila_clavata.mRNA.PySp.gff already exists
# Trichonephila_clavata.mRNA.MaSp2B.gff already exists
# Trichonephila_clavata.mRNA.CrSp.gff already exists
# Trichonephila_clavata.mRNA.MaSp3B.gff already exists
# Trichonephila_clavata.mRNA.AgSp2.gff already exists
# Trichonephila_clavata.mRNA.Pflag.gff already exists
# Trichonephila_clavata.mRNA.MaSp3.gff already exists
# Trichonephila_clavata.mRNA.MiSp.gff already exists
# Trichonephila_clavata.mRNA.AgSp1.gff already exists
# Indexing Araneus_ventricosus already exists
# Alignment Araneus_ventricosus already exists
# mRNA gff file already exists
# Total number of spidroins in Araneus_ventricosus: 17
# ['MaSp1', 'Flag', 'MaSp2', 'Spidroin', 'Ampullate_spidroin', 'AcSp', 'MaSp', 'Putative_spidroin', 'CySp', 'PySp', 'MaSp2B', 'MaSp3B', 'AgSp2', 'Pflag', 'MaSp3', 'MiSp', 'AgSp1']
# Araneus_ventricosus.mRNA.MaSp1.gff already exists
# Araneus_ventricosus.mRNA.Flag.gff already exists
# Araneus_ventricosus.mRNA.MaSp2.gff already exists
# Araneus_ventricosus.mRNA.Spidroin.gff already exists
# Araneus_ventricosus.mRNA.Ampullate_spidroin.gff already exists
# Araneus_ventricosus.mRNA.AcSp.gff already exists
# Araneus_ventricosus.mRNA.MaSp.gff already exists
# Araneus_ventricosus.mRNA.Putative_spidroin.gff already exists
# Araneus_ventricosus.mRNA.CySp.gff already exists
# Araneus_ventricosus.mRNA.PySp.gff already exists
# Araneus_ventricosus.mRNA.MaSp2B.gff already exists
# Araneus_ventricosus.mRNA.MaSp3B.gff already exists
# Araneus_ventricosus.mRNA.AgSp2.gff already exists
# Araneus_ventricosus.mRNA.Pflag.gff already exists
# Araneus_ventricosus.mRNA.MaSp3.gff already exists
# Araneus_ventricosus.mRNA.MiSp.gff already exists
# Araneus_ventricosus.mRNA.AgSp1.gff already exists

# %%
spidroins = ['Pflag', 'MaSp1', 'AcSp', 'MaSp3B', 'Putative_spidroin',
'PySp', 'MaSp3', 'AgSp1', 'AgSp2', 'MaSp2B', 'MaSp', 'Ampullate_spidroin',
'Flag', 'CrSp', 'CySp', 'MiSp', 'MaSp2', 'Spidroin'
]
all_gff_records = []
for spidroin in spidroins:
    # spidroin = "MiSp"
    spider = "Trichonephila_clavata"
    output_dir = f"{miniprot_output_path}/{spider}_all"
    spidroin_gff = f"{output_dir}/{spider}.mRNA.{spidroin}.gff"
    attr_dict = {}
    spidroin_gff_data = []
    with open(spidroin_gff, 'r') as f:
        for line in f:
            if line.startswith('#'):
                continue

            fields = line.strip().split('\t')

            # Analysis of the attributes field
            for attr in fields[8].split(';'):
                if '=' in attr:
                    key, value = attr.split('=', 1)
                    attr_dict[key] = value

            # Create attributes object
            attr_obj = Attributes(
                ID=attr_dict['ID'],
                Rank=int(attr_dict['Rank']),
                Identity=float(attr_dict['Identity']),
                Positive=float(attr_dict['Positive']),
                Target=attr_dict['Target'].split('|')
            )

            # Create gff_data object and add to list
            spidroin_gff_data.append(GFFData(
                seqid=fields[0],
                source=fields[1],
                type=fields[2],
                start=int(fields[3]),
                end=int(fields[4]),
                score=float(fields[5]),
                strand=fields[6],
                frame=fields[7],
                attributes=attr_obj
            ))

    # Sort by positive with descending order
    spidroin_gff_data.sort(key=lambda x: x.attributes.Positive, reverse=True)
    # Extract positions
    positions = extract_positions_from_gff(spidroin_gff_data, positive_threshold=0.5)
    # Export data
    # Export CSV data
    csv_output = spidroin_gff.replace('.gff', '.csv')
    df = positions_export(positions, csv_output, format='csv')

    # Export GFF data
    gff_output = spidroin_gff.replace('.gff', '.combined.gff')
    gff_records = positions_export(positions, gff_output, format='gff', spidroin=spidroin)

    all_gff_records.extend(gff_records)

# Convert to DataFrame and save
if all_gff_records:
    df_combined = pd.DataFrame(all_gff_records)
    # Sort by seqid (chromosome) and start position with natural sorting
    df_combined['seqid_sort'] = df_combined['seqid'].str.extract(r'(\d+)').astype(float)
    df_combined = df_combined.sort_values(['seqid_sort', 'start']).drop('seqid_sort', axis=1)
    # Write to GFF file
    with open(f"{PROCESSED_DATA_DIR}/{spider}_combined.gff", 'w') as f:
        f.write("##gff-version 3\n")
        df_combined.to_csv(f, sep='\t', header=False, index=False)
else:
    print(f"No GFF records to combine for {spider}")
# Out:
# 2025-10-09 09:34:32.808 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Pflag.csv
# 2025-10-09 09:34:32.812 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 1
# 2025-10-09 09:34:32.812 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 0
# 2025-10-09 09:34:32.813 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 1
# 2025-10-09 09:34:32.813 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Pflag.combined.gff
# 2025-10-09 09:34:32.814 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 0
# 2025-10-09 09:34:32.855 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp1.csv
# 2025-10-09 09:34:32.855 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 472
# 2025-10-09 09:34:32.855 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 11
# 2025-10-09 09:34:32.856 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 461
# 2025-10-09 09:34:32.857 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp1.combined.gff
# 2025-10-09 09:34:32.858 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 11
# 2025-10-09 09:34:32.869 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.AcSp.csv
# 2025-10-09 09:34:32.869 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 109
# 2025-10-09 09:34:32.869 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 1
# 2025-10-09 09:34:32.870 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 108
# 2025-10-09 09:34:32.870 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.AcSp.combined.gff
# 2025-10-09 09:34:32.870 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 1
# 2025-10-09 09:34:32.875 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp3B.csv
# 2025-10-09 09:34:32.875 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 17
# 2025-10-09 09:34:32.875 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 4
# 2025-10-09 09:34:32.875 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 13
# 2025-10-09 09:34:32.876 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp3B.combined.gff
# 2025-10-09 09:34:32.876 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 4
# 2025-10-09 09:34:32.877 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Putative_spidroin.csv
# 2025-10-09 09:34:32.878 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 0
# 2025-10-09 09:34:32.878 | WARNING  | spider_silkome_module.export:_export_to_csv:184 - No data to export
# 2025-10-09 09:34:32.878 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.Putative_spidroin.combined.gff
# 2025-10-09 09:34:32.878 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 0
# 2025-10-09 09:34:32.890 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.PySp.csv
# 2025-10-09 09:34:32.890 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 429
# 2025-10-09 09:34:32.891 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 2
# 2025-10-09 09:34:32.891 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 427
# 2025-10-09 09:34:32.892 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.PySp.combined.gff
# 2025-10-09 09:34:32.892 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 2
# 2025-10-09 09:34:32.899 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp3.csv
# 2025-10-09 09:34:32.899 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 238
# 2025-10-09 09:34:32.899 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 8
# 2025-10-09 09:34:32.899 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 230
# 2025-10-09 09:34:32.900 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.MaSp3.combined.gff
# 2025-10-09 09:34:32.900 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: 8
# 2025-10-09 09:34:32.911 | INFO     | spider_silkome_module.export:_export_to_csv:178 - CSV saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.AgSp1.csv
# 2025-10-09 09:34:32.911 | INFO     | spider_silkome_module.export:_export_to_csv:179 - Total combinations: 43
# 2025-10-09 09:34:32.912 | INFO     | spider_silkome_module.export:_export_to_csv:181 - Valid combinations: 1
# 2025-10-09 09:34:32.912 | INFO     | spider_silkome_module.export:_export_to_csv:182 - Invalid combinations: 42
# 2025-10-09 09:34:32.912 | INFO     | spider_silkome_module.export:_export_to_gff:267 - GFF saved to /home/gyk/project/spider_silkome/data/interim/miniprot/Trichonephila_clavata_all/Trichonephila_clavata.mRNA.AgSp1.combined.gff
# 2025-10-09 09:34:32.912 | INFO     | spider_silkome_module.export:_export_to_gff:268 - Total genes predicted: